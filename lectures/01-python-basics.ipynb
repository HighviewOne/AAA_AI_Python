# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %%
df = pd.read_csv('data.csv')
print (df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
new_df=df.dropna()
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
df_inplace = pd.read_csv('data.csv')
df_inplace.dropna(inplace = True)
print (df_inplace.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
df_fill = pd.read_csv('data.csv')
df_fill.fillna(130,inplace = True)
print (df_fill.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     130.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df_fill_calories = pd.read_csv('data.csv')
df_fill_calories.fillna({"Calories" : 130}, inplace = True)
print (df_fill_calories.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     130.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df_4 = pd.read_csv('data4.csv')
print (df_4.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        60.0  110.0     130.0     409.1
# 1        60.0  117.0     145.0     479.0
# 2         NaN  103.0     135.0     340.0
# 3        45.0  109.0     175.0     282.4
# 4        45.0  117.0     148.0       NaN
# 5        60.0  102.0       NaN     300.0
# 6        60.0  110.0     136.0     374.0
# 7        45.0    NaN     134.0     253.3
# 8        30.0  109.0     133.0     195.1
# 9        60.0   98.0     124.0     269.0
# 10       60.0  103.0     147.0     329.3
# 11       60.0  100.0     120.0     250.7
# 12       60.0  106.0     128.0     345.3
# 13       60.0  104.0     132.0     379.3
# 14       60.0   98.0     123.0     275.0
# 15       60.0   98.0     120.0     215.2
# 16       60.0  100.0     120.0     300.0
# 17       45.0   90.0     112.0       NaN
# 18       60.0  103.0     123.0     323.0
# 19       45.0   97.0     125.0     243.0
# 20       60.0  108.0     131.0     364.2
# 21       45.0  100.0     119.0     282.0
# ...

# %%
df_4_fill_calories = pd.read_csv('data4.csv')
df_4_fill_calories.fillna({"Calories" : 130}, inplace = True)
print (df_4_fill_calories.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        60.0  110.0     130.0     409.1
# 1        60.0  117.0     145.0     479.0
# 2         NaN  103.0     135.0     340.0
# 3        45.0  109.0     175.0     282.4
# 4        45.0  117.0     148.0     130.0
# 5        60.0  102.0       NaN     300.0
# 6        60.0  110.0     136.0     374.0
# 7        45.0    NaN     134.0     253.3
# 8        30.0  109.0     133.0     195.1
# 9        60.0   98.0     124.0     269.0
# 10       60.0  103.0     147.0     329.3
# 11       60.0  100.0     120.0     250.7
# 12       60.0  106.0     128.0     345.3
# 13       60.0  104.0     132.0     379.3
# 14       60.0   98.0     123.0     275.0
# 15       60.0   98.0     120.0     215.2
# 16       60.0  100.0     120.0     300.0
# 17       45.0   90.0     112.0     130.0
# 18       60.0  103.0     123.0     323.0
# 19       45.0   97.0     125.0     243.0
# 20       60.0  108.0     131.0     364.2
# 21       45.0  100.0     119.0     282.0
# ...

# %%
df_4_fill_calories_mean = pd.read_csv('data4.csv')
x = df_4_fill_calories_mean["Calories"].mean()
df_4_fill_calories.fillna({"Calories" : x}, inplace = True)
print (df_4_fill_calories.to_string())
print(x)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        60.0  110.0     130.0     409.1
# 1        60.0  117.0     145.0     479.0
# 2         NaN  103.0     135.0     340.0
# 3        45.0  109.0     175.0     282.4
# 4        45.0  117.0     148.0     130.0
# 5        60.0  102.0       NaN     300.0
# 6        60.0  110.0     136.0     374.0
# 7        45.0    NaN     134.0     253.3
# 8        30.0  109.0     133.0     195.1
# 9        60.0   98.0     124.0     269.0
# 10       60.0  103.0     147.0     329.3
# 11       60.0  100.0     120.0     250.7
# 12       60.0  106.0     128.0     345.3
# 13       60.0  104.0     132.0     379.3
# 14       60.0   98.0     123.0     275.0
# 15       60.0   98.0     120.0     215.2
# 16       60.0  100.0     120.0     300.0
# 17       45.0   90.0     112.0     130.0
# 18       60.0  103.0     123.0     323.0
# 19       45.0   97.0     125.0     243.0
# 20       60.0  108.0     131.0     364.2
# 21       45.0  100.0     119.0     282.0
# ...

# %%
df_5 = pd.read_csv('data5.csv')
print (df_5.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    102       127     300.0
# 7          60    110       136     374.0
# 8          45    104       134     253.3
# 9          30    109       133     195.1
# 10         60     98       124     269.0
# 11         60    103       147     329.3
# 12         60    100       120     250.7
# 13         60    106       128     345.3
# 14         60    104       132     379.3
# 15         60    104       132     379.3
# 16         60     98       123     275.0
# 17         60     98       120     215.2
# 18         60    100       120     300.0
# 19         45     90       112       NaN
# 20         60    103       123     323.0
# 21         45     97       125     243.0
# ...

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(np.__version__)
# Out:
# 2.1.3

# %%
arr = np.array([[1,2,3],[4,5,6]])
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr = np.array([[[1,2,3],[4,5,6]],[[1,2,3],[4,5,6]]])
print(arr)
# Out:
# [[[1 2 3]
#   [4 5 6]]
#
#  [[1 2 3]
#   [4 5 6]]]

# %%
import scipy

print(scipy.__version__)
# Out:
# 1.15.3

# %%
Cat and Dog

# %%
import os

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import pyplot

# %%
from matplotlib.image import imread

# %%
import matplotlib.image as mpimg

# %%
from zipfile import ZipFile

# %%
data_path = 'archive.zip'

# %%
with ZipFile(data_path, 'r') as zip:
    zip.extractall()
    print('The data set has been extracted.')
# Out:
# The data set has been extracted.

# %%
fig = plt.gcf()
fig.set_size_inches(16, 16)

# %%
cat_dir = os.path.join('training_set/training_set/cats')
print(cat_dir)
# Out:
# training_set/training_set/cats

# %%
cat_names = os.listdir(cat_dir)

# %%
pic_index = 210

# %%
cat_images = [os.path.join(cat_dir, fname)
              for fname in cat_names[pic_index-8:pic_index]]

# %%
for i, img_path in enumerate(cat_images):
    sp = plt.subplot(4, 4, i+1)
    sp.axis('Off')

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %%
dog_dir = os.path.join('training_set/training_set/dogs')
print(dog_dir)
# Out:
# training_set/training_set/dogs

# %%
dog_names = os.listdir(dog_dir)

# %%
dog_images = [os.path.join(dog_dir, fname)
              for fname in dog_names[pic_index-8:pic_index]]

# %%
for i, img_path in enumerate(dog_images):
    sp = plt.subplot(4, 4, i+1)
    sp.axis('Off')

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()

# %%
import tensorflow as tf
